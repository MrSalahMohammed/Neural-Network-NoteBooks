# %% [markdown]
# <a href="https://colab.research.google.com/github/MrSalahMohammed/Neural-Network-NoteBooks/blob/main/1_NN_fasion_mnist.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras

# %%
mnists = keras.datasets.fashion_mnist
(train_images, train_labels), (test_images, test_labels) = mnists.load_data()
# Out:
# ...
# 4422102/4422102 [==============================] - 1s 0us/step

# %%
class_names = ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat',
               'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']

# %%
train_images = train_images / 255.0
test_images = test_images / 255.0

# %%
import matplotlib.pyplot as plt
for i in range(100):
    plt.subplot(10, 10, i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(train_images[i], cmap=plt.cm.binary)
plt.show()

# %%
model = keras.Sequential([
    keras.layers.Flatten(input_shape=(28, 28)),
    keras.layers.Dense(512, activation='relu'),
    keras.layers.Dense(128, activation='tanh'),
    keras.layers.Dense(10, activation='softmax')
])

# %%
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %%
model.fit(train_images, train_labels, epochs=10)
# Out:
# Epoch 1/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.4508 - accuracy: 0.8353
# Epoch 2/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.3492 - accuracy: 0.8705
# Epoch 3/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.3158 - accuracy: 0.8822
# Epoch 4/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.2900 - accuracy: 0.8918
# Epoch 5/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.2729 - accuracy: 0.8974
# Epoch 6/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.2584 - accuracy: 0.9022
# Epoch 7/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.2456 - accuracy: 0.9075
# Epoch 8/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.2358 - accuracy: 0.9099
# Epoch 9/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.2255 - accuracy: 0.9143
# Epoch 10/10
# ...

# %%
test_loss, test_acc = model.evaluate(test_images,  test_labels, verbose=2)

print('\nTest accuracy:', test_acc)
# Out:
# 313/313 - 1s - loss: 0.3148 - accuracy: 0.8911 - 645ms/epoch - 2ms/step
#
# Test accuracy: 0.8910999894142151
